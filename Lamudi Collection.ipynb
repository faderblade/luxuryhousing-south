# %%
from splinter import Browser
from bs4 import BeautifulSoup as bs
from webdriver_manager.chrome import ChromeDriverManager
import time
import math
import pandas as pd
import requests

# %%
#Get 100 pages
page = 100
counter = 0

# %%
# Setup splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# Looking for [chromedriver 95.0.4638.54 win32] driver in cache
# File found in cache by path [C:\Users\USER\.wdm\drivers\chromedriver\95.0.4638.54\win32\chromedriver.exe]

# %%
list_bathrooms=[]
list_bedrooms=[]
list_rooms_total=[]
list_building_size=[]
list_car_spaces=[]
list_category=[]
list_furnished=[]
list_coordinates=[]
list_location=[]
list_land_size=[]
list_price=[]
list_id=[]
list_subcategory=[]
list_year_built=[]
list_description=[]
list_link=[]

# %%
for i in range(0,page):
    counter = counter + 1 
    counter_str = str(counter)
    url = 'https://www.lamudi.com.ph/cavite/tagaytay/house/buy/price:30000000+/?page=' + counter_str
    browser.visit(url)
    time.sleep(1)
    html = browser.html
    soup = bs(html, 'html.parser')
    
    des=[]
    features = soup.find_all('div', class_="ListingCell-AllInfo ListingUnit")
    other_features = soup.find_all('a', class_= 'js-listing-link ellipsis')
    
    for i in features:
        extra_features=soup.find_all('div', class_="ListingCell-shortDescription")
        for i in range(len(extra_features)):
            d=extra_features[i].get_text(strip = True).replace("\n\n", "").replace("\n", " ").replace("\t", "").replace("\xa0", "")
            des.append(d) 
    loc=[]        
    location=soup.find_all('span', class_="ListingCell-KeyInfo-address-text")
    for i in range(len(location)):
        l=location[i].get_text(strip = True).replace("\n\n", "").replace("\n", " ")
        loc.append(l) 
        
    for i in range(0,30):
      
        try:
            bathrooms=features[i]['data-bathrooms']
            list_bathrooms.append(bathrooms)
        except:
            bathrooms="uknown"
            list_bathrooms.append(bathrooms)  
            
        try:    
            bedrooms=features[i]['data-bedrooms']
            list_bedrooms.append(bedrooms)       
        except:
            bedrooms="unknown"
            list_bedrooms.append(bedrooms)
                
        try:
            rooms_total=features[i]['data-rooms_total']
            list_rooms_total.append(rooms_total)
        except:
            rooms_total="unknown"
            list_rooms_total.append(rooms_total)

            
        try:    
            building_size=features[i]['data-building_size']
            list_building_size.append(building_size)
        except:
            building_size="unknown"
            list_building_size.append(building_size)          

            
        try:
            car_spaces=features[i]['data-car_spaces']
            list_car_spaces.append(car_spaces)   
        except:
            car_spaces="unknown"
            list_car_spaces.append(car_spaces)

            
        try:
            category=features[i]['data-category']
            list_category.append(category)
        except:
            category="unknown"
            list_category.append(category)

            
        try:
            furnished=features[i]['data-furnished']
            list_furnished.append(furnished)
        except:
            furnished="unknown"
            list_furnished.append(furnished)

            
        try:
            coordinates=features[i]['data-geo-point']
            list_coordinates.append(coordinates)
        except:
            coordinates="unknown"
            list_coordinates.append(coordinates)
            
        try:
            location=loc[i]
            list_location.append(location)
        except:
            location="unknown"
            list_location.append(location)    

            
        try:
            land_size=features[i]['data-land_size']
            list_land_size.append(land_size)
        except:
            land_size="unknown"
            list_land_size.append(land_size)

            
        try:
            price=features[i]['data-price']
            list_price.append(price)
        except:
            price="unknown"
            list_price.append(price)

            
        try:
            id=features[i]['data-sku']
            list_id.append(id)
        except:
            id="unknown"
            list_id.append(id)

            
        try:
            subcategory=features[i]['data-subcategories']
            list_subcategory.append(subcategory)
        except:
            subcategory="unknown"
            list_subcategory.append(subcategory)

            
        try:
            year_built=features[i]['data-year_built']
            list_year_built.append(year_built)
        except:
            year_built="unknown"
            list_year_built.append(year_built)

            
        try:
            description=des[i]
            list_description.append( description)
        except:
            description="unknown"
            list_description.append( description)

            
        try:
            link=other_features[i]['href']
            list_link.append(link)
        except:
            link="unknown"
            list_link.append(link)

# %%
dict = {"bathrooms":list_bathrooms,
        "bedrooms":list_bedrooms,
        "rooms_total":list_rooms_total,
        "building_size":list_building_size,
        "car_spaces":list_car_spaces,
        "category":list_category,
        "furnished":list_furnished,
        "coordinates":list_coordinates,
        "location":list_location,
        "land_size":list_land_size,
        "price":list_price,
        "id":list_id,
        "subcategory":list_subcategory,
        "year_built": list_year_built,
        "description":list_description,
        "link":list_link
        }

# %%
df = pd.DataFrame(dict)
df
# Out:
#      bathrooms bedrooms rooms_total building_size car_spaces category  \
# 0            5        5     unknown           461    unknown    house
# 1            6        5           7           652          3    house
# 2            5        5          10          1000          6    house
# 3            3        5           7           320          2    house
# 4           11       10     unknown           670          4    house
# ...        ...      ...         ...           ...        ...      ...
# 2995         5        5     unknown           500    unknown    house
# 2996         4        4     unknown           400    unknown    house
# 2997         5        5           5           400          3    house
# 2998         3        4     unknown           370    unknown    house
# 2999    uknown  unknown     unknown       unknown    unknown  unknown
#
#      furnished               coordinates                          location  \
# 0      unknown   [121.0088385,14.260047]                          Tagaytay
# 1      unknown      [121.2567,14.145351]          Calabuso North, Tagaytay
# 2           38     [121.37702,14.143625]                Calabuso, Tagaytay
# 3               [121.0358238,14.1456011]                Calabuso, Tagaytay
# 4           38  [120.9673014,14.1179125]                San Jose, Tagaytay
# ...        ...                       ...                               ...
# 2995   unknown     [121.04211,14.469863]  Marcelo Green Village, Parañaque
# 2996   unknown     [121.04211,14.469863]  Marcelo Green Village, Parañaque
# 2997        39     [121.04211,14.469863]  Marcelo Green Village, Parañaque
# 2998               [121.04211,14.469863]  Marcelo Green Village, Parañaque
# 2999   unknown                   unknown                           unknown
#
#      land_size      price                    id  \
# 0          306   47000000     HO6099E48BC5D1BPH
# 1          500   40000000     HO5B98D8B6713D2PH
# 2         3152  150000000  NO814HO54NHDINTRESPH
# 3          485   35000000  NO310HO94LEJINTRESPH
# 4          273   32000000     HO5DA299423C60DPH
# ...        ...        ...                   ...
# 2995       350   35000000     HO617C0709D7105PH
# 2996      1131   35000000     HO5E6085B505209PH
# 2997       350   35000000     HO6184CD5F4B2F0PH
# 2998      1124   33000000     HO5D0F3EB69E7EEPH
# 2999   unknown    unknown               unknown
#
#                           subcategory year_built  \
# 0     ["house","single-family-house"]    unknown
# 1     ["house","single-family-house"]    unknown
# 2     ["house","single-family-house"]    unknown
# 3     ["house","single-family-house"]       2016
# 4     ["house","single-family-house"]    unknown
# ...                               ...        ...
# 2995  ["house","single-family-house"]    unknown
# 2996  ["house","single-family-house"]    unknown
# 2997  ["house","single-family-house"]       2021
# 2998  ["house","single-family-house"]    unknown
# 2999                          unknown    unknown
#
#                                             description     link
# 0     Weather of Baguio, view of tagaytay, heated po...  unknown
# 1     OVERLOOKING TAAL LAKE and VOLCANOComplete Hous...  unknown
# 2     House and Lot for Sale with swimming pool, mul...  unknown
# 3     House with pool in Tagaytay Highlands 3br 5tb ...  unknown
# 4     Brand newFully furnished10 bedroom all with ow...  unknown
# ...                                                 ...      ...
# 2995  Price: Php 35,000,000Lot area: 350 SQM Floor a...  unknown
# 2996  Up for sale is a beautifully renovated 4BR hom...  unknown
# 2997  Sophisticated Inviting Brandnew HOUSE and LOT ...  unknown
# 2998  The Property4-bedroom home meticulously remode...  unknown
# 2999  BF Homes Northwest, Parañaque New 2 Storey Hou...  unknown
#
# [3000 rows x 16 columns]

# %%
df.to_csv('tagaytay_luxuryhouses_csv')

# %%
browser.quit()
